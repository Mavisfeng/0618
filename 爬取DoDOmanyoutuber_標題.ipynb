# %% [markdown]
# <a href="https://colab.research.google.com/github/Mavisfeng/0618/blob/main/%E7%88%AC%E5%8F%96DoDOmanyoutuber_%E6%A8%99%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安裝所需套件
# !pip install google-api-python-client

from googleapiclient.discovery import build

# 定義你的 API Key（從 Google Cloud Console 獲取）
API_KEY = 'AIzaSyAjkvZktxgHI0-6LPZ0QYQre_f15Q_vlGk'

# 初始化 YouTube API
youtube = build('youtube', 'v3', developerKey=API_KEY)

# 獲取特定 Youtuber 的頻道 ID
def get_channel_id(channel_name):
    search_response = youtube.search().list(
        q=channel_name,
        part='snippet',
        type='channel',
        maxResults=1
    ).execute()
    return search_response['items'][0]['id']['channelId']

# 獲取頻道內的所有影片
def get_video_titles(channel_id):
    video_titles = []
    next_page_token = None

    while True:
        playlist_response = youtube.search().list(
            channelId=channel_id,
            part='snippet',
            maxResults=50,
            order='date',
            type='video',
            pageToken=next_page_token
        ).execute()

        for item in playlist_response['items']:
            video_titles.append(item['snippet']['title'])

        next_page_token = playlist_response.get('nextPageToken')

        if not next_page_token:
            break

    return video_titles

# 輸入你想搜尋的 Youtuber 名字
channel_name = "The DoDo Men - 嘟嘟人"
channel_id = get_channel_id(channel_name)

# 獲取影片標題
titles = get_video_titles(channel_id)

# 輸出結果
print(f"影片標題（共 {len(titles)} 筆）:")
for idx, title in enumerate(titles, 1):
    print(f"{idx}. {title}")
# Out:
# ...
# 影片標題（共 381 筆）:
# 1. 泳渡美國最難逃監獄！被恐懼吞噬游到崩潰...
# 2. 模仿GD有成功嗎？
# 3. 住進世界最高樹屋是什麼體驗？用滑索才能抵達的神秘樹屋！？
# 4. 獨家開箱美國馬戲團超驚險訓練！危險又迷人的職業！
# 5. 走進非洲最大貧民窟，這裡的真實生活震撼所有人...
# 6. 【鐵人三項全記錄】EP1：人生清單最恐懼的一項！🔥
# 7. 今年聖誕節這樣玩交換禮物！#thedodomen
# 8. 大家覺得跟老闆一起去員工旅遊是加班嗎😆
# 9. 丹麥鮮肉和台灣女孩露營約會！浪漫到以為在演戀愛實境秀！💕
# 10. 連台北人都不知道的秘境？！帶丹麥鮮肉體驗他秒被圈粉！
# 11. 來開箱走鐘獎獎盃🏆
# 12. 走鐘獎首度奪獎！向主持前輩取經挑戰臨場反應！Feat. 好多創作者
# 13. 丹麥鮮肉初次約會台灣女生！拍下兩人超甜互動💕會在一起嗎？
# 14. 遲來的iPhone16 Pro開箱但是絕對不會缺席的！！！😍 #thedodomen
# 15. 史上最硬爬山行程！被印尼Rinjani火山虐爆！火山口超震撼！🔥
# 16. 大家忽略掉的iPhone 16 Pro包裝細節跟今年Apple的包裝大突破！
# 17. 偷偷飛到美國給Eric生日驚喜！驚喜突襲會成功嗎？
# 18. 在台北101上班原來這麼爽！酒喝到飽跟特殊的員工福利！
# 19. 公路車新手一路從台北騎到高雄！有史以來最漫長的體能挑戰！ft. @eLunfitness
# 20. Coffee, Tea or Me？
# 21. 腿軟抽筋的體能挑戰！完全低估這越野接力賽！
# 22. 探索巴黎真實生活！工作假期也太多！美食浪漫之都適合居住嗎？
# 23. 上次在網路滑到這個迷因覺得太真實，決定來致敬一下，因為完全就是我們兩個人啊😂 #thedodomen
# 24. 和創作者們的傳手機挑戰 #thedodomen
# 25. 從法國隨機帶外國人回台灣！第一次來亞洲就帶他去花蓮！
# 26. 這次親眼見到 Novak Djokovic 真的太開心了！雖然沒有一起打到球！但還是很滿足～希望有機會真的能在台上切磋兩下🤣 #thedodomen
# 27. 教世界頂級F1賽車手台式騎車🔥整場催落、超愛小籠包！
# ...
